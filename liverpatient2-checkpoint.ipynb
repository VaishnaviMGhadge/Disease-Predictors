# %%
import pandas as pd
import numpy as np
df=pd.read_csv('indian_liver_patient.csv')
df.head(10)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
# 5   46    Male              1.8               0.7                   208
# 6   26  Female              0.9               0.2                   154
# 7   29  Female              0.9               0.3                   202
# 8   17    Male              0.9               0.3                   202
# 9   55    Male              0.7               0.2                   290
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
# 5                        19                          14             7.6
# 6                        16                          12             7.0
# 7                        14                          11             6.7
# 8                        22                          19             7.4
# 9                        53                          58             6.8
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1
# 5      4.4                        1.30        1
# 6      3.5                        1.00        1
# 7      3.6                        1.10        1
# 8      4.1                        1.20        2
# 9      3.4                        1.00        1

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df2=df.dropna()
df2
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [579 rows x 11 columns]

# %%
df2.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
df2.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %%
df2['Gender']
df2
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [579 rows x 11 columns]

# %%
d1=pd.get_dummies(df2['Gender'])
d1
# Out:
#      Female  Male
# 0         1     0
# 1         0     1
# 2         0     1
# 3         0     1
# 4         0     1
# ..      ...   ...
# 578       0     1
# 579       0     1
# 580       0     1
# 581       0     1
# 582       0     1
#
# [579 rows x 2 columns]

# %%
#merging
df3=pd.concat([d1,df2],1)
df3
# Out:
#      Female  Male  Age  Gender  Total_Bilirubin  Direct_Bilirubin  \
# 0         1     0   65  Female              0.7               0.1
# 1         0     1   62    Male             10.9               5.5
# 2         0     1   62    Male              7.3               4.1
# 3         0     1   58    Male              1.0               0.4
# 4         0     1   72    Male              3.9               2.0
# ..      ...   ...  ...     ...              ...               ...
# 578       0     1   60    Male              0.5               0.1
# 579       0     1   40    Male              0.6               0.1
# 580       0     1   52    Male              0.8               0.2
# 581       0     1   31    Male              1.3               0.5
# 582       0     1   38    Male              1.0               0.3
#
#      Alkaline_Phosphotase  Alamine_Aminotransferase  \
# 0                     187                        16
# 1                     699                        64
# 2                     490                        60
# 3                     182                        14
# 4                     195                        27
# ..                    ...                       ...
# 578                   500                        20
# 579                    98                        35
# 580                   245                        48
# 581                   184                        29
# 582                   216                        21
#
#      Aspartate_Aminotransferase  Total_Protiens  Albumin  \
# 0                            18             6.8      3.3
# 1                           100             7.5      3.2
# 2                            68             7.0      3.3
# 3                            20             6.8      3.4
# 4                            59             7.3      2.4
# ..                          ...             ...      ...
# 578                          34             5.9      1.6
# 579                          31             6.0      3.2
# 580                          49             6.4      3.2
# 581                          32             6.8      3.4
# 582                          24             7.3      4.4
#
#      Albumin_and_Globulin_Ratio  Dataset
# 0                          0.90        1
# 1                          0.74        1
# 2                          0.89        1
# 3                          1.00        1
# 4                          0.40        1
# ..                          ...      ...
# 578                        0.37        2
# 579                        1.10        1
# 580                        1.00        1
# 581                        1.00        1
# 582                        1.50        2
#
# [579 rows x 13 columns]

# %%
#dropping
df4=df3.drop(['Gender','Female'],axis=1)
df4
# Out:
#      Male  Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0       0   65              0.7               0.1                   187
# 1       1   62             10.9               5.5                   699
# 2       1   62              7.3               4.1                   490
# 3       1   58              1.0               0.4                   182
# 4       1   72              3.9               2.0                   195
# ..    ...  ...              ...               ...                   ...
# 578     1   60              0.5               0.1                   500
# 579     1   40              0.6               0.1                    98
# 580     1   52              0.8               0.2                   245
# 581     1   31              1.3               0.5                   184
# 582     1   38              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# 1                          64                         100             7.5
# 2                          60                          68             7.0
# 3                          14                          20             6.8
# 4                          27                          59             7.3
# ..                        ...                         ...             ...
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0        3.3                        0.90        1
# 1        3.2                        0.74        1
# 2        3.3                        0.89        1
# 3        3.4                        1.00        1
# 4        2.4                        0.40        1
# ..       ...                         ...      ...
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2
#
# [579 rows x 11 columns]

# %%
X=df4.drop(['Dataset','Total_Protiens','Albumin_and_Globulin_Ratio','Albumin'],axis=1)
X
# Out:
#      Male  Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0       0   65              0.7               0.1                   187
# 1       1   62             10.9               5.5                   699
# 2       1   62              7.3               4.1                   490
# 3       1   58              1.0               0.4                   182
# 4       1   72              3.9               2.0                   195
# ..    ...  ...              ...               ...                   ...
# 578     1   60              0.5               0.1                   500
# 579     1   40              0.6               0.1                    98
# 580     1   52              0.8               0.2                   245
# 581     1   31              1.3               0.5                   184
# 582     1   38              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase
# 0                          16                          18
# 1                          64                         100
# 2                          60                          68
# 3                          14                          20
# 4                          27                          59
# ..                        ...                         ...
# 578                        20                          34
# 579                        35                          31
# 580                        48                          49
# 581                        29                          32
# 582                        21                          24
#
# [579 rows x 7 columns]

# %%
y=df4['Dataset']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 578    2
# 579    1
# 580    1
# 581    1
# 582    2
# Name: Dataset, Length: 579, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
select=SelectKBest(score_func=chi2,k='all')
fit=select.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-ecce1350d86e> in <module>
#       2 from sklearn.feature_selection import chi2
#       3 select=SelectKBest(score_func=chi2,k='all')
# ----> 4 fit=select.fit(X,y)
#
# ~/.local/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     342         self : object
#     343         """
# --> 344         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc'],
#     345                                    multi_output=True)
#     346
#
# ~/.local/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Female'

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-0134bce13c03> in <module>
# ----> 1 dfscores = pd.DataFrame(fit.scores_)
#       2 dfcolumns = pd.DataFrame(X.columns)
#
# NameError: name 'fit' is not defined

# %%
featureScores = pd.concat([dfscores,dfcolumns],axis=1)
featureScores
# Out:
#              0                           0
# 0    10.605760                         Age
# 1    32.743740                      Gender
# 2    52.442793             Total_Bilirubin
# 3    30.174002            Direct_Bilirubin
# 4   101.495434        Alkaline_Phosphotase
# 5  1581.726919    Alamine_Aminotransferase
# 6  2774.080303  Aspartate_Aminotransferase

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)

# %%
from sklearn.svm import SVC
model2=SVC(kernel='linear')
model2
# Out:
# SVC(kernel='linear')

# %%
model2.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
print(X_test)
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 499   55       3              3.6               1.6                   349
# 403   65       3              0.7               0.2                   199
# 485   22       4              6.7               3.2                   850
# 103   55       4              0.8               0.2                   225
# 122   58       3              1.7               0.8                   188
# ..   ...     ...              ...               ...                   ...
# 505   32       3             32.6              14.1                   219
# 46    21       3              3.9               1.8                   150
# 418   50       3              4.2               2.3                   450
# 523   50       3              0.6               0.2                   137
# 92    60       3              8.6               4.0                   298
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase
# 499                        40                          70
# 403                        19                          22
# 485                       154                         248
# 103                        14                          23
# 122                        60                          84
# ..                        ...                         ...
# 505                        95                         235
# 46                         36                          27
# 418                        69                          50
# 523                        15                          16
# 92                        412                         850
#
# [116 rows x 7 columns]

# %%
print(y_test)
# Out:
# 499    3
# 403    3
# 485    4
# 103    4
# 122    3
#       ..
# 505    3
# 46     3
# 418    3
# 523    3
# 92     3
# Name: Gender, Length: 116, dtype: int64

# %%
y_pred=model2.predict(X_test)
y_pred
# Out:
# array([3, 3, 4, 4, 3, 4, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3,
#        3, 4, 3, 3, 3, 4, 4, 4, 3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 4, 3, 3, 3, 4, 3, 3, 3, 4, 4, 3, 4, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 4, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3,
#        4, 3, 3, 3, 3, 4, 4, 3, 4, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
#        4, 3, 3, 3, 3, 3])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[90  0]
#  [ 0 26]]

# %%
import pickle

# %%
with open('model2_pickle','wb') as f:
    pickle.dump(model2,f)
